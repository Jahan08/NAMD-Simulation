# %% [markdown]
# Example commands

# %%
print ("VMD/NAMD course")
# Out:
# VMD/NAMD course

# %%
x = 10

# %%
print (x)
# Out:
# 10

# %%
! pwd
# Out:
# /content

# %%
! ls
# Out:
# sample_data

# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
! ls

# %%
! ls
# Out:
# sample_data

# %% [markdown]
# # **NAMD without GPU's**

# %%
# !wget https://www.ks.uiuc.edu/Research/namd/2.14/download/946183/NAMD_2.14_Linux-x86_64-multicore.tar.gz

# %%
# !tar -zxf /content/NAMD_2.14_Linux-x86_64-multicore.tar.gz

# %%
# !pwd

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore/namd2 +auto-provision /content/drive/MyDrive/run/Minimization.conf > /content/drive/MyDrive/run/Minimization.log

# %% [markdown]
# # **NAMD with GPU's**

# %%
# !wget https://www.ks.uiuc.edu/Research/namd/2.14/download/946183/NAMD_2.14_Linux-x86_64-multicore-CUDA.tar.gz

# %%
# !tar -zxf /content/NAMD_2.14_Linux-x86_64-multicore-CUDA.tar.gz

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore-CUDA/namd2 +auto-provision /content/drive/MyDrive/run/Minimization.conf  > /content/drive/MyDrive/run/Minimization.log

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore-CUDA/namd2 +auto-provision /content/drive/MyDrive/run/Annealing.conf  > /content/drive/MyDrive/run/Annealing.log

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore-CUDA/namd2 +auto-provision /content/drive/MyDrive/run/Equilibration.conf  > /content/drive/MyDrive/run/Equilibration.log

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore-CUDA/namd2 +auto-provision /content/drive/MyDrive/run/MD.conf  > /content/drive/MyDrive/run/MD.log

# %% [markdown]
# # ***This is the NAMD run for inputs from CHARMM-GUI ***

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore-CUDA/namd2 +auto-provision  /content/drive/MyDrive/charmm-gui-4096485896/namd/step4_equilibration.inp > /content/drive/MyDrive/charmm-gui-4096485896/namd/step4_equilibration.log

# %%
# !/content/NAMD_2.14_Linux-x86_64-multicore-CUDA/namd2 +auto-provision /content/drive/MyDrive/charmm-gui-2920795003/namd/step5_production.inp  > /content/drive/MyDrive/charmm-gui-2920795003/namd/step5_production.log
